# %% [markdown]
# В данном ноутбуке производится аугментация вопросов для большей вариативности.

# %% [markdown]
# ![](https://sun9-70.userapi.com/impg/DJKgUFWYI2pUBmMcFvMVbsbvMqACdR1akb1C_w/xqY5fGmwghI.jpg?size=1280x720&quality=96&sign=014c5802183b9776123f975492101e1d&type=album)

# %% [markdown]
# Мы решили использовать TF-IDF т.к в каждом вопросе встречается ключевое слово (к примеру "налоговая"), с помощью этого алгоритма легко найти важные слова.
# Мы также используем эмбеддинги для того, чтобы учитывать все предложение в целом - оно может иметь определенный окрас, который поможет нам найти ответ для вопроса.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install natasha

# %%
import pandas as pd

# %%
answer_class = pd.read_csv('/content/drive/MyDrive/хаки/ЦФО/answer_class.csv')

# %%
answer_class.iloc[0]['Answer']
# Out:
# 'После успешного прохождения выпускных испытаний вы получите документ, подтверждающий уровень ваших компетенций. Подробнее - https://gb.ru/academiccertificates'

# %% [markdown]
# #аугментация

# %%
train_data = pd.read_csv('/content/drive/MyDrive/хаки/ЦФО/train_data.csv')

# %%
train_data['Question'].values[0]
# Out:
# 'Что делать, если я хочу изменить группу или специализацию во время обучения?'

# %%
gen_qw = ["Что делать, если я хочу изменить направление или специализацию во время обучения?",
"Какие разделы включены в основной курс в личном кабинете?",
"Какие услуги по трудоустройству предоставляет ваша школа? Какие инструменты или ресурсы будут предоставлены студентам?",
"Каково расписание каникул на 2024 год, пожалуйста?",
"Какие инструменты и ресурсы доступны для поиска работы после окончания обучения?",
"Кто осуществляет проверку моих сданных работ?",
"Когда я получу свой диплом?",
"Какая последовательность курсов в моей программе?",
"Где найти информацию о расписании курсов и лекций?",
"Когда нужно оплатить обучение, чтобы получить удостоверение?",
"Как исправить оценку 'не принято'?",
"Как сдать домашнее задание на платформе?",
"Какие программы и инструменты мне нужны для обучения в тестировании?",
"Как я могу получить помощь с трудоустройством?",
"Где узнать о документах или сертификатах после окончания обучения?",
"Где можно посмотреть трансляции вебинаров?",
"Как отключить уведомления от вашей платформы?",
"Когда будет опубликовано расписание?",
"Как получить окончательный документ об образовании?",
"Как настроить уведомления о предстоящих уроках в моем профиле?",
"Могу ли я получить бумажный диплом?",
"Где найти список курсов, которые я должен пройти?",
"Что включено в основное обучение в личном кабинете?",
"Как долго будет длиться мое обучение?",
"Какие программы и инструменты мне нужны для обучения в программировании?",
"Что представляет собой консультация?",
"Что включено в помощь с трудоустройством?",
"В чем разница между программой профессиональной переподготовки и программой повышения квалификации по структуре и длительности?",
"Ожидать ли интерактивные уроки с возможностью задавать вопросы?",
"Где проходят занятия?",
"Есть ли в вашей программе мероприятия или ресурсы для помощи с трудоустройством после обучения?",
"Как получить диплом?",
"Как добавить информацию о себе в профиль?",
"Где найти задание для выполнения?",
"В какие дни проходят уроки?",
"Когда будет доступна запись вебинара?",
"Что делать, если моя налоговая служба не принимает договор с вашей школой?",
"Какой документ я получу после обучения?",
"С какой даты начинается срок обучения для возможных переводов?",
"Как проходят занятия на курсе?",
"В чем основные различия между программой профессиональной переподготовки и программой повышения квалификации?",
"Нужно ли обязательно проходить курсы в разделе 'Отдельные'?",
"В чем разница между программами 'Специалис' и 'Специалист с опытом'?",
"Как начать обучение?",
"Я студент, изучающий специализацию 'Тестировщик'. Какие программы мне следует установить для эффективного обучения?",
"Что представляют собой курсы в разделе 'Отдельные'?",
"Как перевестись в другую группу?",
"Как получить помощь с трудоустройством?",
"Какие программные требования для специализации Программист?",
"Какие документы необходимо предоставить для получения диплома?",
"Где найти список курсов на сайте GeekBrains?",
"Где найти записи прошедших вебинаров?",
"Можно ли пересдать работу, если пропущен дедлайн пересдачи?",
"Можно ли получить налоговый вычет с обучения?",
"Как устроена программа обучения?",
"Какие форматы обучения доступны?",
"При каких условиях можно получить удостоверение?",
"Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?",
"Какие аккредитации или сертификаты можно ожидать после обучения?",
"Что делать, если я пропустил онлайн-урок?",
"Будут ли каникулы в этом году?",
"Как включить уведомления об уроках?",
"Как попасть на урок?",
"Как получить документ после обучения?",
"Можно ли получить налоговый вычет за курсы?",
"Как добавить информацию осебе в учетную запись?",
"Какие варианты сдачи заданий доступны?",
"Что делать, если налоговая отказывается принять договор с вашей школой?",
"Каков формат уроков в моей программе?"]


gen_qw1 = [
    "Что делать, если во время обучения захочется сменить группу или специализацию?",
    "Каковы основные разделы в личном кабинете во время обучения?",
    "Какие инструменты и ресурсы включены в программу помощи с трудоустройством? Какие возможности предоставляются студентам?",
    "Подскажите расписание каникул на 2024 год.",
    "Какие инструменты и ресурсы предоставляются для поиска работы после окончания обучения?",
    "Кто осуществляет проверку моих сданных работ?",
    "Когда можно ожидать получения диплома?",
    "Какова последовательность курсов в программе обучения?",
    "Где можно найти информацию о расписании курсов и лекций?",
    "Когда нужно оплатить обучение, чтобы получить удостоверение?",
    "Как исправить оценку 'не принято'?",
    "Как сдать домашнее задание на платформе?",
    "Какие программы и инструменты нужны для обучения на тестировщике?",
    "Как получить помощь с трудоустройством?",
    "Где можно узнать о документах или сертификатах после завершения обучения?",
    "Где можно посмотреть трансляции вебинаров?",
    "Как отключить уведомления от платформы?",
    "Когда будет доступно расписание?",
    "Как получить итоговый документ об образовании?",
    "Как настроить уведомления о предстоящих уроках в профиле?",
    "Могу ли я получить диплом на бумаге?",
    "Как найти список курсов для прохождения?",
    "Что входит в подготовку в основном обучении в личном кабинете?",
    "Сколько продлится мое обучение?",
    "Какие программы и инструменты нужны для обучения на программисте?",
    "Что представляет собой консультация?",
    "Что включает в себя помощь с трудоустройством?",
    "Как отличается структура и длительность программ профессиональной переподготовки и программ повышения квалификации?",
    "Будут ли уроки интерактивными и позволят ли задавать вопросы?",
    "Где проходят уроки?",
    "Включены ли в программу обучения мероприятия или ресурсы, помогающие с трудоустройством после обучения?",
    "Как забрать диплом?",
    "Как добавить информацию о себе в профиль?",
    "Где найти задание для выполнения?",
    "В какие дни проводятся уроки?",
    "Когда будут доступны записи вебинаров?",
    "Как поступить, если налоговая служба не принимает договор с школой?",
    "Какой документ получу после обучения?",
    "С какой даты начинается срок обучения для возможных переводов?",
    "Как проходят занятия на курсе?",
    "В чем разница между программами профессиональной переподготовки и программами повышения квалификации?",
    "Нужно ли проходить все курсы в разделе 'Отдельные'?",
    "В чем отличие между программами 'Специалист' и 'Специалист с опытом'?",
    "Как начать обучение?",
    "Какие программы мне нужны для обучения на тестировщике?",
    "Что включены в курсы, которые находятся в разделе 'Отдельные'?",
    "Как перейти в другую группу?",
    "Как получить помощь с трудоустройством?",
    "Какие программные требования для специализации Программист?",
    "Какие документы нужно предоставить для получения диплома?",
    "Где на сайте GeekBrains найти список курсов?",
    "Где найти записи прошедших вебинаров?",
    "Можно ли пересдать работу, если пропущен дедлайн пересдачи?",
    "Можно ли получить налоговый вычет с обучения?",
    "Как устроена программа обучения?",
    "Какие форматы обучения доступны?",
    "При каких условиях можно получить удостоверение?",
    "Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?",
    "Какие аккредитации или сертификаты можно получить после обучения?",
    "Что делать, если пропущен онлайн-урок?",
    "Будут ли каникулы в этом году?",
    "Как включить уведомления об уроках?",
    "Как попасть на урок?",
    "Как получить документ после обучения?",
    "Можно ли получить налоговый вычет за обучение?",
    "Как добавить информацию о себе в учетную запись?",
    "Какие варианты сдачи заданий доступны?",
    "Что делать, если налоговая не принимает договор с школой?",
    "Каков формат уроков в моей программе?"
]

gen_qw2 = [
    "Эй, если я вдруг захочу сменить свою группу или специализацию, что делать?",
    "Что там в личном кабинете? Не могу удержаться, хочу знать!",
    "Чего только не включено в программу помощи с трудоустройством! Интересно, какие еще инструменты предоставляются студентам?",
    "Что, как, когда? Расписание каникул на 2024 год - вот это информация!",
    "Ага, а какие еще инструменты и ресурсы предоставляются для поиска работы после окончания обучения?",
    "Что за караул, кто проверяет мои работы?!",
    "У меня уже пульс учащается, когда же я получу свой диплом?",
    "Чему учиться-то сначала?",
    "Ооо, где же это расписание курсов и лекций?",
    "Когда, когда? Когда оплатить обучение, чтобы получить удостоверение?",
    "Как это, 'не принято'? Надо исправлять!",
    "Снова домашка! Как ее сдавать-то на этой платформе?",
    "Я такой волнующийся, что мне нужно для обучения на тестировщике?",
    "Какая помощь с трудоустройством? Сразу хочу знать!",
    "Потомки потомков моих потомков будут узнавать о моих документах и сертификатах! Где их искать?",
    "О, вебинары! Где их смотреть?",
    "Отключить уведомления, пожалуйста, немедленно!",
    "А я уже тут в ожидании расписания!",
    "Не терпится получить итоговый документ!",
    "Уведомления о предстоящих уроках? Давайте это сделаем!",
    "Как же я мечтаю о бумажном дипломе!",
    "Где же список курсов? Ну скажите мне!",
    "Что же меня ждет в основном обучении? Расскажите!",
    "Сколько времени займет это приключение?",
    "Программирование, да? Что мне нужно для старта?",
    "Нужна помощь, нужна! Куда обратиться?",
    "Что же входит в эту помощь с трудоустройством?",
    "Чем отличаются эти программы, интересно?",
    "Интерактивные уроки? Вот это прикольно! Где они?",
    "Уроки, да? Где-то здесь?",
    "А вот мероприятия для трудоустройства?",
    "Диплом! Как его получить?!",
    "Профиль, профиль... Что там добавить о себе?",
    "Где моя домашка? Не могу найти!",
    "Когда будут уроки? Не могу дождаться!",
    "Когда записи вебинаров будут доступны?",
    "Налоговая меня беспокоит! Что делать?",
    "Какой документ получу в конце?",
    "Когда начинается срок обучения для переводов?",
    "Что происходит на занятиях?",
    "В чем разница между этими программами?",
    "Нужно ли проходить все курсы в разделе 'Отдельные'?",
    "Ага, а что с 'Специалистом' и 'Специалистом с опытом'?",
    "Погнали учиться! Как это сделать?",
    "Ооо, тестировщик! Что мне надо?",
    "Эти курсы в 'Отдельные' - что там?",
    "Как я могу перейти в другую группу?",
    "Трудоустройство... Нужна помощь!",
    "Программист? Какие нужны программы?",
    "Документы, документы... Что предоставить?",
    "Где найти список курсов?",
    "Где найти записи вебинаров?",
    "Можно ли пересдать работу, если пропущен дедлайн?",
    "Налоговый вычет, можно?",
    "Программа обучения - это интересно!",
    "Какие есть форматы обучения?",
    "При каких условиях можно получить удостоверение?",
    "Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?",
    "Какие сертификаты можно получить после обучения?",
    "Пропустил онлайн-урок... Что делать?",
    "Будут ли каникулы?",
    "Как включить уведомления об уроках?",
    "Как попасть на урок?",
    "Где взять свой документ?",
    "Можно ли получить налоговый вычет за обучение?",
    "Как добавить информацию о себе в учетную запись?",
    "Какие варианты сдачи заданий есть?",
    "Налоговая не принимает договор - что делать?",
    "Каков формат уроков в моей программе?"
]

gen_qw3 = [
    "Что делать, если вдруг захочется поменять группу или специализацию?",
    "Что вообще там в личном кабинете? Я ничего не понимаю...",
    "В этой программе помощи с трудоустройством что есть? И как мне это понять?",
    "Когда у нас будут каникулы? Я совсем запутался в этом расписании...",
    "Что нужно делать, чтобы найти работу после окончания обучения? Я вообще ничего не знаю об этом...",
    "Кто вообще проверяет мои работы? Меня это очень беспокоит...",
    "Когда, наконец, получу свой диплом? Я так и не понял...",
    "Какая вообще последовательность курсов? Меня это совсем запутало...",
    "Где найти расписание курсов и лекций? Я что-то пропустил...",
    "Когда нужно платить за обучение, чтобы получить удостоверение? Я в этом ничего не понимаю...",
    "Как можно исправить оценку 'не принято'? Я вообще не знаю, как это делать...",
    "Как я могу сдать домашнее задание на этой платформе? Я что-то потерялся...",
    "Что нужно для обучения на тестировщике? Я не понимаю, что мне делать...",
    "Как можно получить помощь с трудоустройством? Мне это совсем не понятно...",
    "Где найти информацию о документах или сертификатах после окончания обучения? Я в этом полностью запутался...",
    "Где можно посмотреть вебинары? Я даже не знаю, где их искать...",
    "Как отключить уведомления от этой платформы? Меня это начинает раздражать...",
    "Когда будет расписание? Я не могу дождаться...",
    "Как получить документ об образовании? Меня это совсем запутало...",
    "Как настроить уведомления о предстоящих уроках? Я не понимаю, как это сделать...",
    "Могу ли я получить бумажный диплом? Мне нужно разобраться...",
    "Где найти список курсов? Я совсем запутался в этом...",
    "Что включено в основное обучение в личном кабинете? Я не могу понять...",
    "Сколько продлится мое обучение? Я даже не знаю, сколько времени это займет...",
    "Что нужно для обучения на программисте? Меня это вообще интересует...",
    "Что такое консультация? Я не могу разобраться...",
    "Что включено в помощь с трудоустройством? Мне нужно это понять...",
    "В чем разница между программой профессиональной переподготовки и программой повышения квалификации? Я даже не знаю, с чего начать...",
    "Будут ли интерактивные уроки? Мне было бы непонятно без них...",
    "Где вообще проходят уроки? Мне нужно это понять...",
    "Есть ли в программе мероприятия или ресурсы для трудоустройства после обучения? Я даже не знаю...",
    "Как забрать свой диплом? Мне непонятно, как это делать...",
    "Как добавить информацию о себе в профиль? Я не могу понять...",
    "Где мне найти задание для выполнения? Мне это не ясно...",
    "Когда идут уроки? Я даже не помню...",
    "Когда будет запись вебинара? Я совсем забыл...",
    "Моя налоговая не принимает договор с этой школой. Что делать? Я не могу разобраться...",
    "Какой документ я получу после обучения? Я в этом совсем запутался...",
    "С какой даты начинается срок обучения для возможных переводов? Мне это не понятно...",
    "Как проходят занятия на курсе? Мне это не ясно...",
    "В чем отличие между программой профессиональной переподготовки и программой повышения квалификации? Я в этом совсем запутался...",
    "Нужно ли проходить все курсы в разделе 'Отдельные'? Я даже не знаю...",
    "Чем отличаются программы 'Специалист' и 'Специалист с опытом'? Мне это не ясно...",
    "Как начать учиться? Меня это совсем запутало...",
    "Что мне нужно установить для обучения на тестировщике? Мне нужно разобраться...",
    "Что такое курсы, которые находятся в разделе 'Отдельные'? Я вообще ничего не понимаю...",
    "Я хочу перейти в другую группу. Что делать? Я даже не знаю...",
    "Как получить помощь с трудоустройством? Мне это не понятно...",
    "Какие программные требования для специализации программист? Я не могу разобраться...",
    "Какие документы нужно предоставить для получения диплома? Мне это не ясно...",
    "Где на сайте GeekBrains найти список курсов, которые нужно проходить? Я не могу найти...",
    "Где найти записи прошедших вебинаров? Мне это не понятно...",
    "Могу ли я пересдать работу, если пропустил дедлайн? Я вообще не понимаю...",
    "Можно ли получить налоговый вычет за обучение? Я не знаю, можно или нет...",
    "Можете рассказать подробнее о программе обучения? Я в этом совсем запутался...",
    "Какие форматы обучения? Я не могу разобраться...",
    "При каких условиях я могу получить удостоверение? Мне это не ясно...",
    "Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций? Я не знаю...",
    "Какие аккредитации или сертификаты после обучения? Я в этом совсем запутался...",
    "Что делать, если пропустил онлайн-урок? Я в этом не уверен...",
    "Будут ли каникулы в этом году? Мне это не ясно...",
    "Как включить уведомления об уроках? Я не понимаю...",
    "Как попасть на урок? Я вообще не знаю...",
    "Что нужно сделать, чтобы получить документ после обучения? Я в этом совсем запутался...",
    "Можно ли получить налоговый вычет за обучение? Я вообще не уверен...",
    "Как добавить информацию о себе в учетную запись? Я не знаю...",
    "Какие варианты сдачи задания доступны? Мне это не понятно...",
    "Что делать, если налоговая отказывается принять договор с этой школой? Я не знаю...",
    "Каков формат уроков в моей программе? Я в этом совсем не разбираюсь..."
]

# %%
gen_qw4=[
    'Что делать, если я хочу изменить группу или специализацию во время обучения?',
    'Какие возможности обучения предоставляются в личном кабинете?',
    'Что включает в себя программа помощи с трудоустройством в моей школе? Какие инструменты или ресурсы будут доступны студентам?',
    'Каково расписание каникул в 2024 году?',
    'Какие инструменты и ресурсы предоставляются для поиска работы после окончания обучения?',
    'Кто осуществляет проверку моих сданных работ?',
    'Когда я получу диплом?',
    'Какова последовательность курсов в моей программе?',
    'Где могу найти информацию о расписании курсов и лекций?',
    'Когда необходимо оплатить обучение, чтобы получить удостоверение?',
    'Как исправить оценку "не принято"?',
    'Как сдавать домашние задания на платформе?',
    'Какие программы и инструменты мне потребуются для обучения на тестировщика?',
    'Как я могу получить помощь с трудоустройством?',
    'Где можно узнать о документах или сертификатах после окончания обучения?',
    'Где проходят трансляции вебинаров?',
    'Как отключить уведомления от вашей платформы?',
    'Когда будет опубликовано расписание?',
    'Как получить итоговый документ об образовании?',
    'Как настроить уведомления о предстоящих уроках в моем профиле?',
    'Могу ли я получить диплом на бумаге?',
    'Где найти список курсов для моего обучения?',
    'Что включено в основное обучение в личном кабинете?',
    'Сколько продлится мое обучение?',
    'Какие программы и инструменты мне нужны для обучения на программиста?',
    'Что представляет собой консультация?',
    'Что включает в себя помощь с трудоустройством?',
    'Какова разница между программой профессиональной переподготовки и программой повышения квалификации?',
    'Будут ли уроки интерактивными и можно ли задавать вопросы?',
    'Где проходят занятия?',
    'Предусмотрены ли в вашей программе мероприятия или ресурсы для трудоустройства после обучения?',
    'Как получить диплом?',
    'Как добавить информацию о себе в свой профиль?',
    'Где найти задания для выполнения?',
    'Когда проходят уроки?',
    'Когда будет доступна запись вебинара?',
    'Моя налоговая служба не принимает договор с вашей школой. Что делать?',
    'Какой документ я получу по окончании обучения?',
    'От какой даты начнется срок обучения для возможных переводов?',
    'Как проходят занятия на курсе?',
    'Какие основные различия между программой профессиональной переподготовки и программой повышения квалификации?',
    'Необходимо ли проходить все курсы в разделе "Отдельные"?',
    'В чем отличие между программами "Специалист" и "Специалист с опытом"?',
    'С чего начать обучение?',
    'Какие программы мне следует установить для обучения на тестировщика?',
    'Что включают в себя курсы в разделе "Отдельные"?',
    'Как перевестись в другую группу?',
    'Как получить помощь с трудоустройством?',
    'Какие программные требования для специализации Программист?',
    'Какие документы необходимы для получения диплома?',
    'Где на сайте GeekBrains найти список курсов для моего обучения?',
    'Где найти записи прошедших вебинаров?',
    'Могу ли я пересдать работу, если пропустил дедлайн?',
    'Могу ли я получить налоговый вычет за обучение?',
    'Как устроена программа обучения?',
    'Какие форматы обучения предусмотрены?',
    'При каких условиях я получу удостоверение?',
    'Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?',
    'Какие аккредитации или сертификаты я получу по окончании обучения?',
    'Что делать, если я не могу присутствовать на онлайн уроке?',
    'Будут ли каникулы в этом году?',
    'Как включить уведомления о уроках для своего аккаунта?',
    'Как попасть на урок?',
    'Что нужно сделать для получения документа после обучения?',
    'Можно ли получить налоговый вычет за курсы?',
    'Как добавить информацию о себе в профиль?',
    'Какие варианты сдачи заданий доступны?',
    'Что делать, если налоговая отказывается принять договор с вашей школой?',
    'Какие форматы уроков на моей программе?'
]


gen_qw5=[
    'Если я решу поменять свою группу или специализацию, что нужно будет сделать?',
    'Какие функции доступны в личном кабинете для обучения?',
    'Какова программа трудоустройства в вашей школе? Какие инструменты или ресурсы будут доступны студентам?',
    'Можно ли узнать о расписании каникул в 2024 году?',
    'Какие возможности предоставляются для поиска работы после окончания обучения?',
    'Кто ответственен за проверку моих работ?',
    'Когда ожидать получение диплома?',
    'Какие курсы будут доступны в моей программе?',
    'Где можно узнать о расписании занятий и лекций?',
    'Когда нужно оплатить обучение для получения удостоверения?',
    'Как исправить оценку "неуд"?',
    'Как пройти процесс сдачи домашних заданий на платформе?',
    'Какие программы и инструменты рекомендуются для обучения в области тестирования?',
    'Как получить помощь в поиске работы?',
    'Где найти информацию о документах или сертификатах после окончания обучения?',
    'Где проводятся трансляции вебинаров?',
    'Как отключить уведомления от вашей платформы?',
    'Когда будет доступно расписание уроков?',
    'Как получить официальный документ об окончании обучения?',
    'Как настроить уведомления о предстоящих уроках в моем аккаунте?',
    'Можно ли получить диплом на бумаге?',
    'Где найти список курсов для моего обучения?',
    'Что предполагает основное обучение в личном кабинете?',
    'Какова продолжительность моего обучения?',
    'Какие программы и инструменты необходимы для обучения в программировании?',
    'Что включает в себя консультация?',
    'Что предусмотрено в программе трудоустройства?',
    'В чем разница между программами профессиональной переподготовки и программами повышения квалификации?',
    'Будут ли уроки интерактивными и можно ли задавать вопросы?',
    'Где проходят занятия?',
    'Есть ли в программе мероприятия или ресурсы для поиска работы после обучения?',
    'Как получить диплом?',
    'Как добавить свои данные в профиль?',
    'Где найти задания для выполнения?',
    'Когда проходят занятия?',
    'Когда можно будет посмотреть запись вебинара?',
    'Мою налоговую службу не устраивает договор с вашей школой. Как действовать?',
    'Какой документ будет выдан по окончании обучения?',
    'С какой даты начнется срок обучения для возможных переводов?',
    'Как проходят уроки на курсе?',
    'В чем отличие между программой профессиональной переподготовки и программой повышения квалификации?',
    'Обязательно ли проходить все курсы в разделе "Отдельные"?',
    'Как отличаются программы "Специалист" и "Специалист с опытом"?',
    'С чего начать обучение?',
    'Какие программы рекомендуется установить для обучения в тестировании?',
    'Что включает в себя раздел "Отдельные"?',
    'Как перевестись в другую группу?',
    'Как получить помощь в трудоустройстве?',
    'Какие программные требования для специализации Программист?',
    'Какие документы нужно предоставить для получения диплома?',
    'Где на сайте GeekBrains найти список курсов для обучения?',
    'Где найти записи прошедших вебинаров?',
    'Можно ли пересдать работу, если пропустил дедлайн?',
    'Можно ли получить налоговый вычет за обучение?',
    'Как устроена программа обучения?',
    'Какие форматы обучения доступны?',
    'При каких условиях выдается удостоверение?',
    'Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?',
    'Какие сертификаты выдается по окончании обучения?',
    'Что делать, если не получается посетить онлайн урок?',
    'Будут ли каникулы в этом году?',
    'Как включить уведомления о предстоящих уроках?',
    'Как попасть на урок?',
    'Что нужно сделать, чтобы получить документ после обучения?',
    'Можно ли получить налоговый вычет за курсы?',
    'Как добавить информацию о себе в профиль?',
    'Какие способы сдачи заданий доступны?',
    'Что делать, если налоговая не принимает договор с вашей школой?',
    'Какие форматы уроков предусмотрены в моей программе?'
]



gen_qw6=[
    'Если я захочу сменить группу или специализацию, что делать?',
    'Что содержится в обучении в личном кабинете?',
    'Что включает программа помощи с трудоустройством в вашей школе? Какие ресурсы будут доступны студентам?',
    'Скажите, когда будут каникулы в 2024 году.',
    'Какие инструменты и ресурсы предоставляются для трудоустройства после обучения?',
    'Кто осуществляет проверку моих работ?',
    'Когда я получу свой диплом?',
    'Какова последовательность курсов в моей программе?',
    'Где можно найти информацию о расписании занятий и лекций?',
    'Когда нужно оплатить обучение, чтобы получить удостоверение?',
    'Как исправить оценку "не принято"?',
    'Как сдать домашнее задание на платформе?',
    'Какие программы и инструменты необходимы для обучения в тестировании?',
    'Как получить помощь в трудоустройстве?',
    'Где узнать о документах или сертификатах после окончания обучения?',
    'Где проходят вебинары?',
    'Как отключить уведомления от платформы?',
    'Когда будет опубликовано расписание?',
    'Как получить итоговый документ об образовании?',
    'Как настроить уведомления о предстоящих уроках?',
    'Можно ли получить бумажный диплом?',
    'Где найти список курсов для прохождения?',
    'Что включает в себя основное обучение в личном кабинете?',
    'Как долго длится обучение?',
    'Какие программы и инструменты нужны для обучения в программировании?',
    'Что такое консультация?',
    'Что включает в себя помощь с трудоустройством?',
    'В чем разница между программой профессиональной переподготовки и программой повышения квалификации?',
    'Могу ли я ожидать интерактивных уроков и возможность задавать вопросы?',
    'Где проходят занятия?',
    'Есть ли мероприятия или ресурсы для трудоустройства после обучения?',
    'Как получить свой диплом?',
    'Как добавить информацию о себе в профиль?',
    'Где найти задания для выполнения?',
    'Когда проходят занятия?',
    'Когда можно посмотреть запись вебинара?',
    'Моя налоговая служба отказывается принимать договор с вашей школой. Что делать?',
    'Какой документ получу после обучения?',
    'От какой даты начинается обучение для возможных переводов?',
    'Как проходят занятия на курсе?',
    'В чем разница между программой профессиональной переподготовки и программой повышения квалификации?',
    'Необходимо ли проходить все курсы в разделе "Отдельные"?',
    'В чем отличие между программами "Специалист" и "Специалист с опытом"?',
    'Как начать обучение?',
    'Какие программы нужны для обучения в тестировании?',
    'Что такое раздел "Отдельные"?',
    'Как перевестись в другую группу?',
    'Как получить помощь с трудоустройством?',
    'Какие программные требования для специализации Программист?',
    'Какие документы нужно предоставить для получения диплома?',
    'Где найти список курсов для обучения?',
    'Где можно найти записи прошедших вебинаров?',
    'Можно ли пересдать работу, если пропущен дедлайн?',
    'Можно ли получить налоговый вычет за обучение?',
    'Как устроена программа обучения?',
    'Какие форматы обучения предусмотрены?',
    'При каких условиях выдается удостоверение?',
    'Можно ли получить диплом без сдачи промежуточных и итоговых аттестаций?',
    'Какие сертификаты выдается по окончании обучения?',
    'Что делать, если не могу присутствовать на онлайн уроке?',
    'Будут ли каникулы в этом году?',
    'Как включить уведомления о предстоящих уроках?',
    'Как попасть на урок?',
    'Что делать, чтобы получить документ после обучения?',
    'Можно ли получить налоговый вычет за курсы?',
    'Как добавить информацию о себе в профиль?',
    'Какие способы сдачи заданий доступны?',
    'Что делать, если налоговая не принимает договор с вашей школой?',
    'Какие форматы уроков предусмотрены в программе?'
]

gen_qw7=[
    'Как изменить группу или специализацию во время обучения?',
    'Что включено в основное обучение на личном кабинете?',
    'Какие ресурсы и инструменты предоставляет ваша школа для помощи в трудоустройстве студентов?',
    'Пожалуйста, подскажите расписание каникул на 2024 год.',
    'Какие инструменты и ресурсы доступны для поиска работы после окончания обучения?',
    'Кто осуществляет проверку сданных работ?',
    'Когда можно ожидать получение диплома?',
    'Какая последовательность курсов предусмотрена в программе?',
    'Где найти информацию о расписании курсов и лекций?',
    'Когда нужно оплатить обучение, чтобы получить удостоверение?',
    'Как исправить оценку "не принято"?',
    'Как сдать домашнее задание на платформе?',
    'Какие программы и инструменты необходимы для обучения на тестировщике?',
    'Как можно получить помощь с трудоустройством?',
    'Где узнать о документах или сертификатах после завершения обучения?',
    'Где можно найти трансляции вебинаров?',
    'Как отключить уведомления от платформы?',
    'Когда будет доступно расписание?',
    'Как получить итоговый документ об образовании?',
    'Как настроить уведомления о предстоящих уроках в профиле?',
    'Могу ли я получить диплом на бумаге?',
    'Где найти список курсов для прохождения?',
    'Что включено в подготовку в основном обучении в личном кабинете?',
    'Как долго будет длиться обучение?',
    'Какие программы и инструменты необходимы для обучения на программисте?',
    'Что включает в себя консультация?',
    'Что предусмотрено в помощи с трудоустройством?',
    'В чем разница между программой профессиональной переподготовки и программой повышения квалификации?',
    'Будут ли уроки интерактивными и с возможностью задавать вопросы?',
    'Где проходят уроки?',
    'Предусмотрены ли в вашей программе обучения мероприятия или ресурсы для помощи с трудоустройством после обучения?',
    'Как получить диплом?',
    'Как добавить информацию о себе в профиль?',
    'Где найти задания для выполнения?',
    'Какие дни проходят уроки?',
    'Когда появится запись вебинара?',
    'Как поступить, если налоговая служба отказывается принять договор с вашей школой?',
    'Какой документ я получу после обучения?',
    'С какой даты начинается срок обучения для возможных переводов?',
    'Как проходят занятия на курсе?',
    'В чем разница между программой профессиональной переподготовки и программой повышения квалификации?',
    'Нужно ли проходить все курсы во вкладке "Отдельные"?',
    'Чем отличаются программы "Специалист" и "Специалист с опытом"?',
    'Как начать учиться?',
    'Какие программы стоит установить для обучения на специализации "Тестировщик"?',
    'Что представляют собой курсы во вкладке "Отдельные"?',
    'Как перевестись в другую группу?',
    'Как получить помощь с трудоустройством?',
    'Какие программные требования для специализации Программист?',
    'Какие документы нужно предоставить для получения диплома?',
    'Где найти список курсов на сайте GeekBrains?',
    'Где найти записи прошедших вебинаров?',
    'Могу ли я пересдать работу, если пропустил дедлайн?',
    'Можно ли получить налоговый вычет за обучение?',
    'Можете рассказать подробнее о программе обучения?',
    'Какие форматы обучения доступны?',
    'При каких условиях можно получить удостоверение?',
    'Можно ли получить диплом без аттестаций?',
    'Какие аккредитации или удостоверения я могу получить?',
    'Что делать, если я пропустил онлайн-урок?',
    'Будут ли каникулы в этом году?',
    'Как включить уведомления об уроках?',
    'Как попасть на урок?',
    'Что нужно сделать для получения документа после обучения?',
    'Можно ли получить налоговый вычет за прохождение курсов?',
    'Как добавить информацию о себе в учетную запись?',
    'Какие варианты сдачи заданий доступны?',
    'Что делать, если налоговая отказывается принять договор с вашей школой?',
    'Какой формат уроков в моей программе?'
]


gen_qw8 = [
    'Если у меня внезапно возникло желание изменить свою группу или специализацию по ходу обучения, что мне следует предпринять?',
    'Могли бы вы подробно рассказать о том, из каких компонентов состоит основное обучение, предлагаемое в личном кабинете, и о том, какие именно материалы и возможности включаются в это обучение?',
    'Каковы все шаги и инструменты, включенные в программу помощи с трудоустройством вашей школы, и какие именно ресурсы и инструменты будут предоставлены студентам для успешного трудоустройства?',
    'Могли бы вы, пожалуйста, предоставить полное расписание каникул на 2024 год, включая даты начала и окончания каждого периода каникул?',
    'Какие инструменты и ресурсы включены в вашу программу поддержки для поиска работы после окончания обучения, и какие именно опции и инструменты доступны для студентов для успешного трудоустройства?',
    'Кто именно осуществляет проверку моих сданных работ, и какие критерии оценки используются для этой проверки?',
    'Сколько времени в среднем занимает процесс получения диплома после завершения обучения на вашей платформе?',
    'Какова полная последовательность курсов, предусмотренных в программе обучения, и какие именно курсы входят в эту последовательность?',
    'Где и как можно получить полную информацию о расписании курсов и лекций, включая даты, времена и места проведения каждого урока?',
    'Когда именно нужно было внести оплату за обучение, чтобы получить удостоверение об окончании курсов, и какие именно опции оплаты доступны для студентов?',
    'Если у меня есть задание с оценкой "не принято", какие действия я могу предпринять для исправления этой ситуации и получения положительной оценки?',
    'Как точно производится сдача домашнего задания на вашей платформе, включая все необходимые шаги и процессы?',
    'Какие программы и инструменты необходимо установить для эффективного обучения на специализации тестировщика, и какие именно ресурсы и инструменты рекомендуется использовать для успешного освоения материала?',
    'Как именно можно получить помощь с трудоустройством после завершения обучения, включая все предоставляемые услуги и ресурсы для успешного трудоустройства?',
    'Где и как можно найти всю необходимую информацию о документах и сертификатах, которые студенты могут получить после успешного завершения обучения на вашей платформе?',
    'Где происходят все трансляции вебинаров, и как можно получить доступ к просмотру этих трансляций?',
    'Если я не хочу получать уведомления от вашей платформы, каким образом я могу отключить или изменить настройки уведомлений?',
    'Когда можно ожидать получение полного расписания обучения на текущий период?',
    'Как точно можно получить итоговый документ об образовании после завершения обучения, включая все этапы и процессы получения этого документа?',
    'Как настроить оповещения о предстоящих уроках в личном профиле, чтобы всегда быть в курсе предстоящих занятий?',
    'Можно ли запросить получение диплома в печатном виде, и если да, то какие именно шаги нужно предпринять для этого?',
    'Где можно найти список всех курсов, которые студент должен успешно пройти в рамках своего обучения на вашей платформе?',
    'Что включает в себя подготовка, предусмотренная в основном обучении на личном кабинете, и какие именно материалы и ресурсы входят в эту подготовку?',
    'Какой общий период времени требуется для завершения обучения на вашей платформе, включая все курсы и программы?',
    'Какие программы и инструменты необходимо установить для эффективного обучения на специализации программиста, и какие именно ресурсы и инструменты рекомендуется использовать для успешного освоения материала?',
    'Что включает в себя индивидуальная консультация студентов, и какие именно услуги и рекомендации предоставляются в рамках этой консультации?',
    'Какие именно услуги и ресурсы предоставляются в рамках программы поддержки с трудоустройством, и каким образом студенты могут воспользоваться этими возможностями для успешного трудоустройства?',
    'Каковы основные различия в структуре и длительности между программой профессиональной переподготовки и программой повышения квалификации, и какую именно программу стоит выбрать в зависимости от своих целей и потребностей?',
    'Могу ли я ожидать, что уроки будут интерактивными и включать в себя возможность задавать вопросы в реальном времени, и если да, то как это будет осуществляться?',
    'Где именно проходят занятия, и как студенты могут получить доступ к каждому уроку?',
    'Предусмотрены ли в вашей программе обучения какие-либо мероприятия или ресурсы, которые помогут студентам с трудоустройством после завершения обучения, и если да, то какие именно?',
    'Как можно получить диплом, и какие именно шаги и документы требуются для этого?',
    'Как добавить дополнительную информацию о себе в свой профиль на платформе?',
    'Где можно найти все задания, которые нужно выполнить в рамках обучения?',
    'Какие дни недели заняты уроками, и когда конкретно проходят занятия в рамках каждого дня?',
    'Когда можно ожидать доступа к записи прошедшего вебинара, и каким образом это будет осуществляться?',
    'Если моя налоговая служба отказывается принимать договор с вашей школой, какие именно действия мне следует предпринять в этой ситуации?',
    'Какой документ и когда я получу после завершения обучения, и каким образом этот документ будет предоставлен мне?',
    'От какой конкретной даты начинается отсчет срока обучения для возможных переводов, и как это учитывается в рамках обучения на вашей платформе?',
    'Как проходят занятия на курсе, и каким образом структурирован каждый урок?',
    'Какие основные различия между программой профессиональной переподготовки и программой повышения квалификации, и какую из них стоит выбрать, исходя из своих целей и потребностей?',
    'Обязательно ли проходить все курсы во вкладке "Отдельные", и как это повлияет на получение диплома?',
    'В чем конкретно отличия между программами "Специалист" и "Специалист с опытом", и какую из них следует выбрать для успешного обучения?',
    'Как начать учиться на вашей платформе, и какие именно шаги нужно предпринять для этого?',
    'Я студент, изучающий специализацию "Тестировщик" на вашей платформе. Можете ли вы подсказать, какие программы и инструменты мне следует установить для эффективного обучения, и какие именно ресурсы рекомендуется использовать?',
    'Что представляют собой курсы, находящиеся во вкладке "Отдельные", и каким образом они дополняют основное обучение?',
    'Как можно перевестись в другую группу, и какие именно шаги нужно предпринять для этого?',
    'Как именно можно получить помощь с трудоустройством, включая все предоставляемые услуги и инструменты для успешного трудоустройства?',
    'Мне бы хотелось узнать, какие программные требования необходимы для специализации Программист, и какие именно инструменты и ресурсы мне следует использовать?',
    'Какие документы мне нужно предоставить для получения диплома, и каким образом это происходит?',
    'Где именно на сайте GeekBrains я могу найти полный список курсов, которые я должен пройти в рамках своего обучения?',
    'Где я могу найти записи прошедших вебинаров, и как получить к ним доступ?',
    'Могу ли я пересдать работу еще раз, если я пропустил дедлайн пересдачи, и как это сделать?',
    'Можно ли получить налоговый вычет с оплаты обучения, и как это оформляется?',
    'Можете ли вы рассказать подробнее о структуре и организации программы обучения, включая все этапы и компоненты?',
    'Какие доступны форматы обучения на вашей платформе, и какой именно формат обучения будет наиболее эффективным для меня?',
    'При каких условиях я могу получить удостоверение об окончании курсов, и какие именно требования необходимо выполнить для этого?',
    'Возможно ли получить диплом без необходимости сдачи промежуточных и итоговых аттестаций, и если да, то как это осуществить?',
    'Какие аккредитации или удостоверения я могу ожидать получить по завершении обучения, и какие именно возможности сертификации предоставляются?',
    'Что делать, если я не смог присоединиться к онлайн-уроку в назначенное время, и как это повлияет на мое обучение?',
    'Будут ли предусмотрены каникулы на платформе GeekBrains в этом году, и если да, то в какие периоды и на какие сроки?',
    'Как включить уведомления о предстоящих уроках для моего аккаунта, и как настроить их?',
    'Как мне попасть на урок, и каким образом это происходит?',
    'Какие конкретные действия необходимо предпринять, чтобы получить документ об окончании обучения, и какой именно этап процесса завершения обучения является ключевым?',
    'Возможно ли получить налоговый вычет за прохождение курсов на вашей платформе, и если да, то как это оформляется и какие документы нужно предоставить?',
    'Как я могу добавить информацию о себе в мою учетную запись, и каким образом это сделать?',
    'Какие варианты сдачи заданий доступны на вашей платформе, и какой именно вариант сдачи будет для меня наиболее удобным?',
    'Какие действия необходимо предпринять, если налоговая отказывается принять договор с вашей школой, и как это можно разрешить?',
    'Каким образом проходят уроки на моей программе обучения, и какая именно методика обучения используется в рамках каждого урока?'
]

# %%
generated_questions=[gen_qw,gen_qw1,gen_qw2,gen_qw3, gen_qw4, gen_qw5, gen_qw6, gen_qw7, gen_qw8]

# %% [markdown]
# объеденение

# %%
conc_arr=[]
conc_arr.append(train_data)
train_data2=train_data
for q in generated_questions:
  print(q[-1])
  train_data2['Question']=q
  conc_arr.append(train_data2.copy())
# Out:
# Каков формат уроков в моей программе?
# Каков формат уроков в моей программе?
# Каков формат уроков в моей программе?
# Каков формат уроков в моей программе? Я в этом совсем не разбираюсь...
# Какие форматы уроков на моей программе?
# Какие форматы уроков предусмотрены в моей программе?
# Какие форматы уроков предусмотрены в программе?
# Какой формат уроков в моей программе?
# Каким образом проходят уроки на моей программе обучения, и какая именно методика обучения используется в рамках каждого урока?

# %%
train_data = pd.concat(conc_arr,ignore_index=True, axis=0)

# %% [markdown]
# убираем дубликаты

# %%
train_data=train_data.drop_duplicates(subset=['Question'])
train_data.reset_index(inplace=True, drop=True)

# %%
train_data
# Out:
#                                               Question  \
# 0    Если у меня внезапно возникло желание изменить...
# 1    Могли бы вы подробно рассказать о том, из каки...
# 2    Каковы все шаги и инструменты, включенные в пр...
# 3    Могли бы вы, пожалуйста, предоставить полное р...
# 4    Какие инструменты и ресурсы включены в вашу пр...
# ..                                                 ...
# 455  Можете рассказать подробнее о программе обучения?
# 456           Можно ли получить диплом без аттестаций?
# 457  Какие аккредитации или удостоверения я могу по...
# 458  Можно ли получить налоговый вычет за прохожден...
# 459              Какой формат уроков в моей программе?
#
#                      Category  answer_class
# 0    Перевод/ запись в группу            11
# 1                      Портал            15
# 2             Трудоустройство            27
# 3                  Расписание            21
# 4             Трудоустройство            25
# ...

# %%
#train_data.to_csv('aug_train_data.csv',index=False)

# %% [markdown]
# #проверка

# %%
train_data['Category'].unique()
# Out:
# array(['Перевод/ запись в группу', 'Портал', 'Трудоустройство',
#        'Расписание', 'Оценки', 'Документы', 'Организация уроков',
#        'Практические работы', 'Требования ПО', 'Программа обучения'],
#       dtype=object)

# %%
train_data.groupby('Category')['answer_class'].count()
# Out:
# Category
# Документы                   103
# Организация уроков           82
# Оценки                       19
# Перевод/ запись в группу     21
# Портал                       81
# Практические работы          16
# Программа обучения           35
# Расписание                   29
# Требования ПО                31
# Трудоустройство              43
# Name: answer_class, dtype: int64

# %%
train_data.groupby('Category')['answer_class'].unique()
# Out:
# Category
# Документы                   [2, 3, 0, 1, 4, 29, 28]
# Организация уроков                  [6, 5, 8, 7, 9]
# Оценки                                         [10]
# Перевод/ запись в группу                       [11]
# Портал                         [15, 17, 14, 18, 16]
# Практические работы                            [12]
# Программа обучения                     [13, 20, 19]
# Расписание                                 [21, 22]
# Требования ПО                              [24, 23]
# Трудоустройство                        [27, 25, 26]
# Name: answer_class, dtype: object

# %% [markdown]
# #TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=2)

# %%
documents=train_data['Question'].values

# %%
len(documents)
# Out:
# 460

# %% [markdown]
# удаление стоп слов

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("russian"))

# %% [markdown]
# лемматизация

# %%
from natasha import (Segmenter, MorphVocab, NewsEmbedding, NewsMorphTagger, NewsSyntaxParser, NewsNERTagger, PER, NamesExtractor, DatesExtractor, MoneyExtractor, AddrExtractor, Doc)

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)

# %%
def lematizate_sentance(text):
  doc = Doc(text)
  doc.segment(segmenter)
  doc.tag_morph(morph_tagger)

  new_sent=""
  for token in doc.tokens:
      token.lemmatize(morph_vocab)
      if token.lemma not in stop_words:
        new_sent += f"{token.lemma} "
  return new_sent

# %%
def lematizate_sentances(texts):
  new_texts=[]
  for text in texts:
    new_texts.append(lematizate_sentance(text))

  return new_texts

# %%
documents=lematizate_sentances(documents)

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# %%
tfidf_matrix
# Out:
# <460x240 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2399 stored elements in Compressed Sparse Row format>

# %%
tfidf_table = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# %%
import joblib
# Сохранение TfidfVectorizer в файл
joblib.dump(tfidf_vectorizer, "tfidf_vectorizer.pkl")
# Out:
# ['tfidf_vectorizer.pkl']

# %%
tfidf_table
# Out:
#          2024  geekbrains  ага  аккаунт  аккредитация  аттестация  беспокоить  \
# 0    0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# 1    0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# 2    0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# 3    0.260678         0.0  0.0      0.0      0.000000    0.000000         0.0
# 4    0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# ..        ...         ...  ...      ...           ...         ...         ...
# 455  0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# 456  0.000000         0.0  0.0      0.0      0.000000    0.765103         0.0
# 457  0.000000         0.0  0.0      0.0      0.636911    0.000000         0.0
# 458  0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
# 459  0.000000         0.0  0.0      0.0      0.000000    0.000000         0.0
#
# ...

# %%
train_data=pd.concat([train_data,tfidf_table], axis=1)

# %%
train_data
# Out:
#                                               Question  \
# 0    Если у меня внезапно возникло желание изменить...
# 1    Могли бы вы подробно рассказать о том, из каки...
# 2    Каковы все шаги и инструменты, включенные в пр...
# 3    Могли бы вы, пожалуйста, предоставить полное р...
# 4    Какие инструменты и ресурсы включены в вашу пр...
# ..                                                 ...
# 455  Можете рассказать подробнее о программе обучения?
# 456           Можно ли получить диплом без аттестаций?
# 457  Какие аккредитации или удостоверения я могу по...
# 458  Можно ли получить налоговый вычет за прохожден...
# 459              Какой формат уроков в моей программе?
#
#                      Category  answer_class      2024  geekbrains  ага  \
# 0    Перевод/ запись в группу            11  0.000000         0.0  0.0
# 1                      Портал            15  0.000000         0.0  0.0
# 2             Трудоустройство            27  0.000000         0.0  0.0
# ...

# %%
train_data.to_csv('aug_train_data.csv',index=False)
